# %%
for val in sequence:
  loop body

# %%
#program untuk menghitung jumlah semua angka dalam sebuah list
L1=[2,4,5,7,9]
jumlah=0
#iterasi di dalam list
for i in L1:
  jumlah = jumlah + i
print(jumlah)
# Out:
# 27

# %%
#program untuk melakukan iterasi di dalam list melalui indeks
minuman = ["teh","boba","kopi","susu"]
p=len(minuman)
#iterasi di dalam list melalui indeks
for i in range(p):
  print(minuman[i])
# Out:
# teh
# boba
# kopi
# susu

# %%
#contoh for loop menggunakan else
for i in range(p):
  print(minuman[i])
else:
  print("elemen sudah habis")
# Out:
# teh
# boba
# kopi
# susu
# elemen sudah habis

# %%
#Latihan 1
tagihan=[50000,75000,-150000,125000,300000,-50000,200000]
total_tagihan=0
for i in tagihan:
  total_tagihan=total_tagihan+i
print(total_tagihan)
# Out:
# 550000

# %%
while test_expression:
  body of while

# %%
#program untuk menjumlahkan semua
#bilangan asli hingga suku ke-n
#jum = 1+2+3+...+n

n=10
jumlah=0
i=1
while i<=n:
  jumlah=jumlah+i
  i=i+1
print(jumlah)
# Out:
# 55

# %%
jumlah=0
i=1
while i<=n:
  jumlah=jumlah+i
  i=i+1
else:
  print(jumlah)
# Out:
# 55

# %%
tagihan=[50000,75000,125000,300000,200000]
total_tagihan=0
i=0
a=len(tagihan)
while i<a:
  total_tagihan=total_tagihan+tagihan[i]
  i=i+1
print(total_tagihan)
# Out:
# 750000

# %%
if test expression:
  statement(s):

# %%
#jika angka adalah bilangan positif maka print "adalah bilangan positif"

angka=3
if angka > 0:
  print(angka, "adalah bilangan positif.")
print("pernyataan ini selalu ditampilkan.")

angka=-1
if angka > 0:
  print(angka, "adalah bilangan positif.")
print("pernyataan ini selalu ditampilkan.")
# Out:
# 3 adalah bilangan positif.
# pernyataan ini selalu ditampilkan.
# pernyataan ini selalu ditampilkan.

# %%
if test expression:
  body of if
else:
  body of else

# %%
#program disusuun untuuk mengecek apakah angka tersebut kurang dari 0 atau tidak
# dan menampilkan tulisan yang sesuai

angka=3

if angka >=0:
  print("bilangan lebih dari atau sama dengan 0")
else:
  print("bilangan kurang dari 0")
# Out:
# bilangan lebih dari atau sama dengan 0

# %%
#program disusun untuuk mengecek apakah dua buah angka sama atau tidak
#dan menampilkan tulisan yang sesuai
a=5
b=5

if a==b:
  print("a dan b bernilai sama")
else:
  print("a dan b bernilai berbeda")
  print("belajar if else")
# Out:
# a dan b bernilai sama

# %%
#program disusun uuntuk mengecek apakah perbandingan dua buah angka
#dan menampilkan tulisan yang sesuai

#membaca dua angka
bil1=int(input("masukkan bilangan pertama: "))
bil2=int(input("masukkan bilangan kedua :"))
#memilih bilangan yang lebih besar
if bil1>bil2:
  bil_lebih_besar=bil1
else:
  bil_lebih_besar=bil2

#menampilkan hasil
print("bilangan yang lebih besar adalah:", bil_lebih_besar)
# Out:
# masukkan bilangan pertama: 100
# masukkan bilangan kedua :20
# bilangan yang lebih besar adalah: 100

# %%
if test expression:
  body of if
elif test expression:
  body of elif
else:
  body of else

# %%
#program disusun untuk mengecek apakah angka merupakan bilangan positif, negatif dan nol
#dan menampilkan tulisan yang sesuai

angka=3.4
if angka>0:
  print("bilangan positif")
elif angka==0:
  print("nol")
else:
  print("bilangan negatif")
# Out:
# bilangan positif

# %%
#statement if
x=4
if x%2==0: #jika x dibagi 2 samadengan 0
  print("x habis dibagi 2")
#statement if...elif...else
x=7
if x%2==0:
  print("x habis dibagi 2")
elif x%3==0:
  print("x habis dibagi 3")
elif x%5==0:
  print("x habis dibagi 5")
else:
  print("x tidak habis dibagi dua, tiga ataupun 5")
# Out:
# x habis dibagi 2
# x tidak habis dibagi dua, tiga ataupun 5

# %%
#prongram disusun untuk mengecek apakah angka merupakan bilangan positif, negatif atau nol
#dan menampilkan hasil yang sesuai

angka=float(input("masukkan angka :"))
if angka>=0:
  if angka==0:
    print("nol")
  else:
    print("bilangan positif")
else:
  print("bilangan negatif")
# Out:
# masukkan angka :0
# nol
